# %%
import numpy as np 
import pandas as pd 

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\user\Downloads\Crimes_-_2001_to_Present.csv')

# %%
data.shape
# Out:
# (8077151, 22)

# %%
data.head()
# Out:
#          ID Case Number                    Date                      Block  \
# 0   5741943    HN549294  08/25/2007 09:22:18 AM         074XX N ROGERS AVE
# 1     25953    JE240540  05/24/2021 03:06:00 PM        020XX N LARAMIE AVE
# 2     26038    JE279849  06/26/2021 09:24:00 AM      062XX N MC CORMICK RD
# 3  13279676    JG507211  11/09/2023 07:30:00 AM           019XX W BYRON ST
# 4  13274752    JG501049  11/12/2023 07:59:00 AM  086XX S COTTAGE GROVE AVE
#
#    IUCR Primary Type                                        Description  \
# 0  0560      ASSAULT                                             SIMPLE
# 1  0110     HOMICIDE                                FIRST DEGREE MURDER
# 2  0110     HOMICIDE                                FIRST DEGREE MURDER
# 3  0620     BURGLARY                                     UNLAWFUL ENTRY
# 4  0454      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
data.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  8.077151e+06  8.077151e+06  8.077104e+06  7.462305e+06    7.463681e+06
# mean   7.251138e+06  1.184977e+03  1.129740e+01  2.276916e+01    3.743256e+01
# std    3.630950e+06  7.035118e+02  6.958819e+00  1.385516e+01    2.154604e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    3.903034e+06  6.210000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    7.247163e+06  1.034000e+03  1.000000e+01  2.300000e+01    3.200000e+01
# 75%    1.050030e+07  1.731000e+03  1.700000e+01  3.400000e+01    5.700000e+01
# max    1.348547e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  7.988193e+06  7.988193e+06  8.077151e+06  7.988193e+06  7.988193e+06
# mean   1.164621e+06  1.885846e+06  2.010428e+03  4.184236e+01 -8.767142e+01
# ...

# %%
data.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description     13087
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    47
# Ward                    614846
# Community Area          613470
# FBI Code                     0
# X Coordinate             88958
# Y Coordinate             88958
# Year                         0
# Updated On                   0
# Latitude                 88958
# Longitude                88958
# Location                 88958
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame creation (you should load your actual DataFrame)
data = pd.DataFrame({
    'Date': pd.date_range(start='1/1/2020', periods=100, freq='M'),
    'Ward': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C', 'D'] * 10
})

# Print column names to verify
print(data.columns)

# Set figure size and style
plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('dark_background')

# Create the count plot
sns.countplot(x='Ward', data=data, palette='gnuplot')

# Set plot title and rotate x-axis labels
plt.title('Major Crimes in Chicago', fontweight='bold', fontsize=20)
plt.xticks(rotation=90)

# Show the plot
plt.show()
# Out:
# Index(['Date', 'Ward'], dtype='object')
# C:\Users\user\AppData\Local\Temp\ipykernel_8940\67479601.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ward', data=data, palette='gnuplot')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Check available styles
print(plt.style.available)

# Set a valid style
plt.style.use('seaborn-v0_8-pastel')

# Setting plot parameters
plt.rcParams['figure.figsize'] = (20, 9)

# Generating colors
color = plt.cm.spring(np.linspace(0, 1, 15))

# Assuming 'data' is your DataFrame
data['Location Description'].value_counts().plot.bar(color=color)

# Adding title and formatting x-axis labels
plt.title('District with Most Crime', fontsize=30)
plt.xticks(rotation=90)

# Displaying the plot
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# ...

# %%
import matplotlib.pyplot as plt

# Print available styles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# Regions with count of crimes

plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('seaborn-v0_8-pastel')

color = plt.cm.ocean(np.linspace(0, 1, 15))
data['Block'].value_counts().head(15).plot.bar(color = color, figsize = (15, 10))

plt.title('Top 15 Regions in Crime',fontsize = 20)

plt.xticks(rotation = 90)
plt.show()

# %%
plt.style.use('seaborn-v0_8')

color = plt.cm.winter(np.linspace(0, 10, 20))
data['Primary Type'].value_counts().plot.bar(color = color, figsize = (15, 8))

plt.title('Resolutions for Crime',fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame
data = pd.DataFrame({
    'Date': pd.date_range(start='1/1/2020', periods=100, freq='M')
})

# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Extract month from the 'Date' column
data['Month'] = data['Date'].dt.month

# Set the plot style and figure size
plt.style.use('seaborn-v0_8-white')
plt.rcParams['figure.figsize'] = (15, 8)

# Create the count plot
sns.countplot(x='Month', data=data, palette='autumn')
plt.title('Crimes in each Month', fontsize=20)

# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8940\3107365423.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Month', data=data, palette='autumn')

# %%
# !pip install jovian --upgrade -q
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import jovian

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
